# %%
from Generate import *
# Load a demo sample, convert to STFT and back and play the sound.
#demo_stft("Samples/Piano C4 Major 13.wav", 2048, 2048*3//4)
# Out:
# Using sample rate=44100 Hz, FFT=1024 buckets, hop=768 samples
# Using device=cpu

# %%
generator = Sample_Generator()
# Out:
# sizes=[1500, 512, 175, 60]
# SymmetricSTFTAutoEncoder: sequence_length=114, stft_buckets=1024, sizes=[116736, 1500, 512, 175, 60], activation_fn=<class 'torch.nn.modules.activation.ReLU'>
# model=SymmetricSTFTAutoEncoder(
#   (autoencoder): SymmetricAutoEncoder(
#     (encoder_layers): ModuleList(
#       (0): Linear(in_features=116736, out_features=1500, bias=True)
#       (1): Linear(in_features=1500, out_features=512, bias=True)
#       (2): Linear(in_features=512, out_features=175, bias=True)
#       (3): Linear(in_features=175, out_features=60, bias=True)
#     )
#     (decoder_layers): ModuleList(
#       (0): Linear(in_features=60, out_features=175, bias=True)
#       (1): Linear(in_features=175, out_features=512, bias=True)
#       (2): Linear(in_features=512, out_features=1500, bias=True)
#       (3): Linear(in_features=1500, out_features=116736, bias=True)
#     )
#     (activation_fn): ReLU()
#   )
# )
# Loaded 898 STFTs from STFTs.pkl

# %%
#generator.randomise_sample("guitar", 2.0, True, 5)

# %%
generator.interpolate_sample("violin", "piano", True, 7) # Plausible, violin sound is poor

#generator.interpolate_sample("trombone", "piano st c3", True, 7)


#generator.interpolate_no_ai("violin", "piano", True, 7)

#generator.interpolate_sample("bell", "drum", True, 7) # OK 

#generator.interpolate_sample("wavetable", "kalimba", True, 7) # Meh

#generator.interpolate_sample("big buzz", "infection", True, 7) # OK-ish


#generator.interpolate_sample("Analog", "Resonant Sequence", True, 7) # Resonant Sequence is poor

#generator.interpolate_sample("Wet Funk", "Sweep", True, 7) # Poor sweep


#generator.interpolate_no_ai("Analog", "Resonant Sequence", True, 7)
#generator.interpolate_no_ai("big buzz", "infection", True, 7)

# Grunge Drone C3: loss= 0.0838
# Fat And Dirty C3 2: loss= 0.0857
# Modulation Rise And Fall C4: loss= 0.0955
# Analog Epic C3: loss= 0.1541
# Mini 3 VCO Squares C3: loss= 0.4726
# Vocoder Jangle C3 8bts: loss= 0.5358
# Particle 7 Dim C3: loss= 0.6104
# Classic Sync C4: loss= 0.6141

#generator.interpolate_sample("Grunge Drone", "Classic Sync C4")
# Out:
# File Casio-CZ-5000-Violin-C4 matches violin.
# Encoded Casio-CZ-5000-Violin-C4 to torch.Size([1, 60])
# File Ensoniq-ESQ-1-FM-Piano-C4 matches piano.
# Encoded Ensoniq-ESQ-1-FM-Piano-C4 to torch.Size([1, 60])
